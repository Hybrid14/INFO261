# %% [markdown]
# # Objetivos del Notebook
#
# En el trabajo práctico anterior, hemos conversado de algunos principios para diseñar una API web, definiendo puntos para acceder a recursos. Hemos implementando una API web básica en Python con el framework Flask. Este notebook 5 tiene como objetivos:
#
# - utilizar APIs web existentes
#
# - manipular datos al formato JSON utilizando librerias Python para la Ciencia de Datos: Pandas, MatplotLib
#
# - utilizar el SGBD no relacional Mongo describiendo primeras características que lo diferencia de MySQL

# %% [markdown]
# # 1. Utilizar la API OpenAQ
#
# <a href="https://openaq.org">OpenAQ</a> es una iniciativa colaborativa ciudadana y científica que apunta a proveer datos abiertos y herramientas para monitorear y proteger la calidad del aire. Esta comunidad recopiló ~300 millones de medidas del aire en 67 paises.
#
# En particular, OpenAQ toma la forma de:
#
# - una API Web, desarrollada en Javascript (framework Node.js), la cual interactua con el SGBD relacional PostgreSQL. Todo el código está abierto bajo la licencia <i>MIT License</i>: <a href="https://github.com/openaq/openaq-api">OpenAQ-API</a>
#
# - Una aplicación web, desarrollada en Javascript tambien que permite navegar visualmente en los datos: <a href="https://dolugen.github.io/openaq-browser/#/cities">OpenAQ-browser</a>
#
# La documentación de la API se encuentra aqui: <a href="https://docs.openaq.org/">documentación</a>

# %% [markdown]
# <b>Pregunta</b>:
#
# - ¿En algunas palabras cuáles son las características de la licencia MIT License? ¿Cuál es la diferencia principal con la licencia GPL?
# - ¿Cuántos puntos de acceso tiene OpenAQ-API?
# - ¿Cuántas tablas tiene la Base de Datos utilizada por OpenAQ?

# %% [markdown]
# Ejemplo de consulta a OpenAQ-API para responder a la pregunta siguiente:
# <b>¿Cuál es el nivel de contaminación en la ciudad de Valdivia el 29 de octubre 2018?</b>

# %%
# importar la librería Requests que sirve para enviar consultas HTTP
import requests
  
# api-endpoint 
endpoint = "https://api.openaq.org/v1/measurements"
parameters = "?country=CL&city=Valdivia&include_fields=&limit=1000&date_from=2018-10-28&date_to=2018-10-30"
URL = endpoint+parameters

r = requests.get(url = URL) 
  
# extracting data in json format 
data = r.json() 
  
print(data)
# Out:
# {'meta': {'name': 'openaq-api', 'license': 'CC BY 4.0', 'website': 'https://docs.openaq.org/', 'page': 1, 'limit': 1000, 'found': 159}, 'results': [{'location': 'Valdivia', 'parameter': 'pm25', 'date': {'utc': '2018-10-30T00:00:00.000Z', 'local': '2018-10-29T21:00:00-03:00'}, 'value': 21, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'co', 'date': {'utc': '2018-10-30T00:00:00.000Z', 'local': '2018-10-29T21:00:00-03:00'}, 'value': 565.81, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'so2', 'date': {'utc': '2018-10-30T00:00:00.000Z', 'local': '2018-10-29T21:00:00-03:00'}, 'value': 2.71, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'pm10', 'date': {'utc': '2018-10-30T00:00:00.000Z', 'local': '2018-10-29T21:00:00-03:00'}, 'value': 43, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'pm25', 'date': {'utc': '2018-10-29T23:00:00.000Z', 'local': '2018-10-29T20:00:00-03:00'}, 'value': 15, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'pm10', 'date': {'utc': '2018-10-29T23:00:00.000Z', 'local': '2018-10-29T20:00:00-03:00'}, 'value': 25, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'so2', 'date': {'utc': '2018-10-29T23:00:00.000Z', 'local': '2018-10-29T20:00:00-03:00'}, 'value': 2.59, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'co', 'date': {'utc': '2018-10-29T23:00:00.000Z', 'local': '2018-10-29T20:00:00-03:00'}, 'value': 305.49, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'pm10', 'date': {'utc': '2018-10-29T22:00:00.000Z', 'local': '2018-10-29T19:00:00-03:00'}, 'value': 21, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'so2', 'date': {'utc': '2018-10-29T22:00:00.000Z', 'local': '2018-10-29T19:00:00-03:00'}, 'value': 2.47, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'co', 'date': {'utc': '2018-10-29T22:00:00.000Z', 'local': '2018-10-29T19:00:00-03:00'}, 'value': 178.29, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'pm25', 'date': {'utc': '2018-10-29T22:00:00.000Z', 'local': '2018-10-29T19:00:00-03:00'}, 'value': 9, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'pm25', 'date': {'utc': '2018-10-29T21:00:00.000Z', 'local': '2018-10-29T18:00:00-03:00'}, 'value': 10, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'location': 'Valdivia', 'parameter': 'so2', 'date': {'utc': '2018-10-29T21:00:00.000Z', 'local': '2018-10-29T18:00:00-03:00'}, 'value': 2.52, 'unit': 'µg/m³', 'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209}, 'country': 'CL', 'city': 'Valdivia'}, {'locat ...

# %% [markdown]
# El código anterior devuelve un solo objeto JSON bruto, en el cual se encuentra un campo <i>results</i>. El valor del campo <i>results</i> es un arreglo de objetos JSON que corresponden a medidas de la contaminación en Valdivia en distintas fechas.

# %% [markdown]
# Para acceder a valores particulares del JSON, la sintáxis es simple. Por ejemplo, si queremos ver el contenido del campo <i>meta</i>:

# %%
data["meta"]
# Out:
# {'name': 'openaq-api',
#  'license': 'CC BY 4.0',
#  'website': 'https://docs.openaq.org/',
#  'page': 1,
#  'limit': 1000,
#  'found': 159}

# %% [markdown]
# Observen cómo navegar en los distintos elementos del objeto JSON:

# %%
data["meta"]["license"]
# Out:
# 'CC BY 4.0'

# %%
data["results"][0]
# Out:
# {'location': 'Valdivia',
#  'parameter': 'pm25',
#  'date': {'utc': '2018-10-30T00:00:00.000Z',
#   'local': '2018-10-29T21:00:00-03:00'},
#  'value': 21,
#  'unit': 'µg/m³',
#  'coordinates': {'latitude': -39.831316104673, 'longitude': -73.22851282209},
#  'country': 'CL',
#  'city': 'Valdivia'}

# %%
data["results"][1]["coordinates"]["latitude"]
# Out:
# -39.831316104673

# %% [markdown]
# En Python, la librería <a href="https://pandas.pydata.org/">Pandas</a> permite facilitar la manipulación de datos. A continuación, mostramos cómo cargar los datos de la API en una tabla (un "DataFrame" en la terminología de Pandas).

# %%
import pandas as pd

valdivia_df = pd.DataFrame(data['results'])
#Mostramos los 10 primeros resultados
valdivia_df[0:10] #equivalente a: valdivia_df.head(10)
# Out:
#        city                                        coordinates country  \
# 0  Valdivia  {'latitude': -39.831316104673, 'longitude': -7...      CL
# 1  Valdivia  {'latitude': -39.831316104673, 'longitude': -7...      CL
# 2  Valdivia  {'latitude': -39.831316104673, 'longitude': -7...      CL
# 3  Valdivia  {'latitude': -39.831316104673, 'longitude': -7...      CL
# 4  Valdivia  {'latitude': -39.831316104673, 'longitude': -7...      CL
# 5  Valdivia  {'latitude': -39.831316104673, 'longitude': -7...      CL
# 6  Valdivia  {'latitude': -39.831316104673, 'longitude': -7...      CL
# 7  Valdivia  {'latitude': -39.831316104673, 'longitude': -7...      CL
# 8  Valdivia  {'latitude': -39.831316104673, 'longitude': -7...      CL
# 9  Valdivia  {'latitude': -39.831316104673, 'longitude': -7...      CL
#
#                                                 date  location parameter  \
# 0  {'utc': '2018-10-30T00:00:00.000Z', 'local': '...  Valdivia      pm25
# 1  {'utc': '2018-10-30T00:00:00.000Z', 'local': '...  Valdivia        co
# 2  {'utc': '2018-10-30T00:00:00.000Z', 'local': '...  Valdivia       so2
# 3  {'utc': '2018-10-30T00:00:00.000Z', 'local': '...  Valdivia      pm10
# 4  {'utc': '2018-10-29T23:00:00.000Z', 'local': '...  Valdivia      pm25
# 5  {'utc': '2018-10-29T23:00:00.000Z', 'local': '...  Valdivia      pm10
# 6  {'utc': '2018-10-29T23:00:00.000Z', 'local': '...  Valdivia       so2
# 7  {'utc': '2018-10-29T23:00:00.000Z', 'local': '...  Valdivia        co
# 8  {'utc': '2018-10-29T22:00:00.000Z', 'local': '...  Valdivia      pm10
# 9  {'utc': '2018-10-29T22:00:00.000Z', 'local': '...  Valdivia       so2
#
#     unit   value
# 0  µg/m³   21.00
# 1  µg/m³  565.81
# 2  µg/m³    2.71
# 3  µg/m³   43.00
# 4  µg/m³   15.00
# 5  µg/m³   25.00
# 6  µg/m³    2.59
# 7  µg/m³  305.49
# 8  µg/m³   21.00
# 9  µg/m³    2.47

# %% [markdown]
# Las columnas <code>coordinates</code> y <code>date</code> contienen valor de tipo objeto JSON. Para evitar tener problema a continuación con estos valores, normalizamos el dataframe:

# %%
#Fase de normalización que permite transformar un objeto JSON en columnas
from pandas.io.json import json_normalize
data_normalized=json_normalize(data['results'])

valdivia_df = pd.DataFrame(data_normalized)
#Mostramos los 10 primeros resultados
valdivia_df.head(10)
# Out:
#        city  coordinates.latitude  coordinates.longitude country  \
# 0  Valdivia            -39.831316             -73.228513      CL
# 1  Valdivia            -39.831316             -73.228513      CL
# 2  Valdivia            -39.831316             -73.228513      CL
# 3  Valdivia            -39.831316             -73.228513      CL
# 4  Valdivia            -39.831316             -73.228513      CL
# 5  Valdivia            -39.831316             -73.228513      CL
# 6  Valdivia            -39.831316             -73.228513      CL
# 7  Valdivia            -39.831316             -73.228513      CL
# 8  Valdivia            -39.831316             -73.228513      CL
# 9  Valdivia            -39.831316             -73.228513      CL
#
#                   date.local                  date.utc  location parameter  \
# 0  2018-10-29T21:00:00-03:00  2018-10-30T00:00:00.000Z  Valdivia      pm25
# 1  2018-10-29T21:00:00-03:00  2018-10-30T00:00:00.000Z  Valdivia        co
# 2  2018-10-29T21:00:00-03:00  2018-10-30T00:00:00.000Z  Valdivia       so2
# 3  2018-10-29T21:00:00-03:00  2018-10-30T00:00:00.000Z  Valdivia      pm10
# 4  2018-10-29T20:00:00-03:00  2018-10-29T23:00:00.000Z  Valdivia      pm25
# 5  2018-10-29T20:00:00-03:00  2018-10-29T23:00:00.000Z  Valdivia      pm10
# 6  2018-10-29T20:00:00-03:00  2018-10-29T23:00:00.000Z  Valdivia       so2
# 7  2018-10-29T20:00:00-03:00  2018-10-29T23:00:00.000Z  Valdivia        co
# 8  2018-10-29T19:00:00-03:00  2018-10-29T22:00:00.000Z  Valdivia      pm10
# 9  2018-10-29T19:00:00-03:00  2018-10-29T22:00:00.000Z  Valdivia       so2
#
#     unit   value
# 0  µg/m³   21.00
# 1  µg/m³  565.81
# 2  µg/m³    2.71
# 3  µg/m³   43.00
# 4  µg/m³   15.00
# 5  µg/m³   25.00
# 6  µg/m³    2.59
# 7  µg/m³  305.49
# 8  µg/m³   21.00
# 9  µg/m³    2.47

# %% [markdown]
# Como la clausula "SELECT" en SQL, Pandas permite selectionnar las columnas que se quiere mostrar:

# %%
valdivia_df2=valdivia_df[['city','country','date.local','parameter','value']]
#Renombrar la columna "date.local" para simplificar
valdivia_df2 = valdivia_df2.rename(columns={'date.local': 'date'})
valdivia_df2.head(10)
# Out:
#        city country                       date parameter   value
# 0  Valdivia      CL  2018-10-29T21:00:00-03:00      pm25   21.00
# 1  Valdivia      CL  2018-10-29T21:00:00-03:00        co  565.81
# 2  Valdivia      CL  2018-10-29T21:00:00-03:00       so2    2.71
# 3  Valdivia      CL  2018-10-29T21:00:00-03:00      pm10   43.00
# 4  Valdivia      CL  2018-10-29T20:00:00-03:00      pm25   15.00
# 5  Valdivia      CL  2018-10-29T20:00:00-03:00      pm10   25.00
# 6  Valdivia      CL  2018-10-29T20:00:00-03:00       so2    2.59
# 7  Valdivia      CL  2018-10-29T20:00:00-03:00        co  305.49
# 8  Valdivia      CL  2018-10-29T19:00:00-03:00      pm10   21.00
# 9  Valdivia      CL  2018-10-29T19:00:00-03:00       so2    2.47

# %% [markdown]
# Como en SQL, Pandas permite ordenar los resultados (el método <code>sort_values</code> es equivalente al <code>order by</code> en SQL). En nuestro ejemplo, queremos ordenar el resultado según la fecha.

# %%
valdivia_df2.sort_values(['date'],ascending=True).head(10)
# Out:
#          city country                       date parameter   value
# 158  Valdivia      CL  2018-10-27T21:00:00-03:00      pm10   17.00
# 154  Valdivia      CL  2018-10-27T22:00:00-03:00        co  223.51
# 157  Valdivia      CL  2018-10-27T22:00:00-03:00       so2    2.12
# 156  Valdivia      CL  2018-10-27T22:00:00-03:00      pm25   11.00
# 155  Valdivia      CL  2018-10-27T22:00:00-03:00      pm10   19.00
# 152  Valdivia      CL  2018-10-27T23:00:00-03:00       so2    2.09
# 151  Valdivia      CL  2018-10-27T23:00:00-03:00        co  165.49
# 153  Valdivia      CL  2018-10-27T23:00:00-03:00      pm25   17.00
# 150  Valdivia      CL  2018-10-28T00:00:00-03:00       so2    2.09
# 149  Valdivia      CL  2018-10-28T04:00:00-03:00      pm10    7.00

# %% [markdown]
# La API devuelve varias medidas cada hora, por un tema de simplicidad, vamos a generalizar los datos para tener solamente 1 valor por hora y por tipo de particulas. Como en SQL, Pandas tiene un método para agrupar valores. En nuestro ejemplo, agrupamos según el tipo de particula (<code>parameter</code>) y la fecha (<code>date</code>), y conservarmos el promedio de las medidas.

# %%
import numpy as np

valdivia_df3=valdivia_df2.groupby(['parameter','date']).agg(np.average)
valdivia_df3=valdivia_df3.reset_index()
valdivia_df3.head(10)
# Out:
#   parameter                       date   value
# 0        co  2018-10-27T22:00:00-03:00  223.51
# 1        co  2018-10-27T23:00:00-03:00  165.49
# 2        co  2018-10-28T06:00:00-03:00  266.43
# 3        co  2018-10-28T08:00:00-03:00   46.41
# 4        co  2018-10-28T09:00:00-03:00   59.70
# 5        co  2018-10-28T10:00:00-03:00   59.97
# 6        co  2018-10-28T11:00:00-03:00   27.39
# 7        co  2018-10-28T12:00:00-03:00   55.07
# 8        co  2018-10-28T14:00:00-03:00  141.14
# 9        co  2018-10-28T15:00:00-03:00   55.58

# %% [markdown]
# Finalmente, Pandas tambien permite filtrar las filas de una tabla (equivalente del <code>WHERE</code> en SQL). En nuestro ejemplo, creamos 4 dataframes que contienen los datos por cada tipo de particula (co, pm10, pm25 y so2).

# %%
valdivia_df_co=valdivia_df3[(valdivia_df3.parameter=='co')]
valdivia_df_pm10=valdivia_df3[(valdivia_df3.parameter=='pm10')]
valdivia_df_pm25=valdivia_df3[(valdivia_df3.parameter=='pm25')]
valdivia_df_so2=valdivia_df3[(valdivia_df3.parameter=='so2')]
valdivia_df_co.head()
# Out:
#   parameter                       date   value
# 0        co  2018-10-27T22:00:00-03:00  223.51
# 1        co  2018-10-27T23:00:00-03:00  165.49
# 2        co  2018-10-28T06:00:00-03:00  266.43
# 3        co  2018-10-28T08:00:00-03:00   46.41
# 4        co  2018-10-28T09:00:00-03:00   59.70

# %% [markdown]
# Para más detalles sobre la API de Pandas, se puede consultar:
#
# - <a href="https://www.dataquest.io/blog/pandas-cheat-sheet/">Pandas cheat sheet</a>
#
# - <a href="https://pandas.pydata.org/pandas-docs/stable/">Documentación de Pandas</a>

# %% [markdown]
# Una vez que tenemos nuestros datos listos (o "preprocesados"), a menudo se necesita visualizar estos datos de alguna manera. En Python, existen varias librerías de visualización de datos, entre las cuales las más utilizadas son: MatplotLib, Plotly o Geoplotlib. Ejemplo de visualización realizada con Geoplotlib.
#
# <img src="geoplotlib.png"></img>

# %% [markdown]
# Como primer enfoque, a continuación vamos simplemente visualizar un Line Chart mostrando la evolución de la cantidad de CO en Valdivia el día 28 de octubre:

# %%
import matplotlib.pyplot as plt

#Definición del tamaño de la figura
plt.figure(figsize=(15,6))

#Definición de los datos que sirven de eje X e Y
x_co = valdivia_df_co['date']
y_co = valdivia_df_co['value']

#Leyenda
plt.xlabel('Date')
plt.ylabel('Cantidad de CO')
plt.title('Cantidad de CO en Valdivia el día 28 de octubre')
plt.xticks(rotation=90)

#Dibujar la visualización
plt.plot(x_co,y_co)

# %% [markdown]
# <b>Ejercicio:</b>
#
# - Conectarse a la API OpenAQ para saber cuáles los lugares en Chile dónde se recopila medidas de contaminación.

# %%
# importar la librería Requests que sirve para enviar consultas HTTP
import requests 
  
# api-endpoint 
endpoint = "https://api.openaq.org/v1/locations"
parameters = "?country=CL&include_fields"
URL = endpoint+parameters

r = requests.get(url = URL) 
  
# extracting data in json format 
data = r.json() 
  
print(data)
# Out:
# {'results': [{'count': 236, 'city': 'Huasco', 'parameters': ['pm25', 'pm10'], 'location': '21 de Mayo', 'country': 'CL', 'sourceNames': ['Chile - SINCA'], 'sourceName': 'Chile - SINCA', 'coordinates': {'longitude': -71.227295, 'latitude': -28.467794}, 'firstUpdated': '2018-08-31T13:00:00.000Z', 'lastUpdated': '2018-10-31T12:00:00.000Z'}, {'count': 48408, 'city': '21 de mayo', 'parameters': ['pm10', 'pm25'], 'location': '21 de mayo', 'country': 'CL', 'sourceNames': ['Chile - SINCA'], 'sourceName': 'Chile - SINCA', 'coordinates': {'longitude': -72.361465, 'latitude': -37.471184}, 'firstUpdated': '2015-09-23T14:00:00.000Z', 'lastUpdated': '2018-11-22T01:00:00.000Z'}, {'count': 10655, 'city': 'Puerto Montt', 'parameters': ['pm25'], 'location': 'Alerce', 'country': 'CL', 'sourceNames': ['Chile - SINCA'], 'sourceName': 'Chile - SINCA', 'coordinates': {'longitude': -72.89952, 'latitude': -41.39917}, 'firstUpdated': '2017-03-27T23:00:00.000Z', 'lastUpdated': '2018-11-22T01:00:00.000Z'}, {'count': 18900, 'city': 'Alto Hospicio', 'parameters': ['pm25'], 'location': 'Alto Hospicio', 'country': 'CL', 'sourceNames': ['Chile - SINCA'], 'sourceName': 'Chile - SINCA', 'coordinates': {'longitude': -70.10019, 'latitude': -20.290466}, 'firstUpdated': '2016-02-22T18:00:00.000Z', 'lastUpdated': '2018-11-22T01:00:00.000Z'}, {'count': 22799, 'city': 'Andacollo', 'parameters': ['pm10'], 'location': 'Andacollo', 'country': 'CL', 'sourceNames': ['Chile - SINCA'], 'sourceName': 'Chile - SINCA', 'coordinates': {'longitude': -71.08613, 'latitude': -30.227768}, 'firstUpdated': '2015-09-23T13:00:00.000Z', 'lastUpdated': '2018-11-22T01:00:00.000Z'}, {'count': 46957, 'city': 'Antofagasta', 'parameters': ['pm10', 'pm25', 'so2'], 'location': 'Antofagasta', 'country': 'CL', 'sourceNames': ['Chile - SINCA'], 'sourceName': 'Chile - SINCA', 'coordinates': {'longitude': -70.383316, 'latitude': -23.613543}, 'firstUpdated': '2015-09-23T12:00:00.000Z', 'lastUpdated': '2018-11-22T01:00:00.000Z'}, {'count': 21380, 'city': 'Arica', 'parameters': ['pm25'], 'location': 'Arica', 'country': 'CL', 'sourceNames': ['Chile - SINCA'], 'sourceName': 'Chile - SINCA', 'coordinates': {'longitude': -70.29055, 'latitude': -18.483427}, 'firstUpdated': '2015-09-23T13:00:00.000Z', 'lastUpdated': '2018-10-29T16:00:00.000Z'}, {'count': 344, 'city': 'Curanilahue', 'parameters': ['pm25'], 'location': 'Balneario', 'country': 'CL', 'sourceNames': ['Chile - SINCA'], 'sourceName': 'Chile - SINCA', 'coordinates': {'longitude': -73.33163, 'latitude': -37.48513}, 'firstUpdated': '2016-12-02T16:00:00.000Z', 'lastUpdated': '2016-12-28T11:00:00.000Z'}, {'count': 10731, 'city': 'Curanilahue', 'parameters': ['pm25'], 'location': 'Balneario Curanilahue', 'country': 'CL', 'sourceNames': ['Chile - SINCA'], 'sourceName': 'Chile - SINCA', 'coordinates': {'longitude': -73.33163, 'latitude': -37.48513}, 'firstUpdated': '2017-04-27T18:00:00.000Z', 'lastUpdated': '2018-11-22T01:00:00.000Z'}, {'count': 12565, 'city': 'Hualpén', 'parameters': ['pm10'], 'location': 'Bocatoma', 'country': 'CL', 'sourceNames': ['Chile - SINCA'], 'sourceName': 'Chile - SINCA', 'coordinates': {'longitude': -73.12053, 'latitude': -36.803036}, 'firstUpdated': '2016-05-10T20:00:00.000Z', 'lastUpdated': '2018-11-22T01:00:00.000Z'}, {'count': 16636, 'city': 'Bomberos', 'parameters': ['pm25'], 'location': 'Bomberos', 'country': 'CL', 'sourceNames': ['Chile - SINCA'], 'sourceName': 'Chile - SINCA', 'coordinates': {'longitude': -70.21083, 'latitude': -22.111065}, 'firstUpdated': '2015-09-23T13:00:00.000Z', 'lastUpdated': '2018-03-08T20:00:00.000Z'}, {'count': 16863, 'city': 'Coronel', 'parameters': ['so2'], 'location': 'Calabozo', 'country': 'CL', 'sourceNames': ['Chile - SINCA'], 'sourceName': 'Chile - SINCA', 'coordinates': {'longitude': -73.11581, 'latitude': -36.99643}, 'firstUpdated': '2015-09-23T14:00:00.000Z', 'lastUpdated': '2018-11-22T02:00:00.000Z'}, {'count': 34949, 'city': 'Puchuncaví', 'parameters': ['co', 'no2', 'o3', 'so2'], 'loca ...

# %%
import pandas as pd

chile = pd.DataFrame(data['results'])
chile[0:10]
# Out:
#             city                                        coordinates  count  \
# 0         Huasco  {'longitude': -71.227295, 'latitude': -28.467794}    236
# 1     21 de mayo  {'longitude': -72.361465, 'latitude': -37.471184}  48408
# 2   Puerto Montt    {'longitude': -72.89952, 'latitude': -41.39917}  10655
# 3  Alto Hospicio   {'longitude': -70.10019, 'latitude': -20.290466}  18900
# 4      Andacollo   {'longitude': -71.08613, 'latitude': -30.227768}  22799
# 5    Antofagasta  {'longitude': -70.383316, 'latitude': -23.613543}  46957
# 6          Arica   {'longitude': -70.29055, 'latitude': -18.483427}  21380
# 7    Curanilahue    {'longitude': -73.33163, 'latitude': -37.48513}    344
# 8    Curanilahue    {'longitude': -73.33163, 'latitude': -37.48513}  10731
# 9        Hualpén   {'longitude': -73.12053, 'latitude': -36.803036}  12565
#
#   country              firstUpdated               lastUpdated  \
# 0      CL  2018-08-31T13:00:00.000Z  2018-10-31T12:00:00.000Z
# 1      CL  2015-09-23T14:00:00.000Z  2018-11-22T01:00:00.000Z
# 2      CL  2017-03-27T23:00:00.000Z  2018-11-22T01:00:00.000Z
# 3      CL  2016-02-22T18:00:00.000Z  2018-11-22T01:00:00.000Z
# 4      CL  2015-09-23T13:00:00.000Z  2018-11-22T01:00:00.000Z
# 5      CL  2015-09-23T12:00:00.000Z  2018-11-22T01:00:00.000Z
# 6      CL  2015-09-23T13:00:00.000Z  2018-10-29T16:00:00.000Z
# 7      CL  2016-12-02T16:00:00.000Z  2016-12-28T11:00:00.000Z
# 8      CL  2017-04-27T18:00:00.000Z  2018-11-22T01:00:00.000Z
# 9      CL  2016-05-10T20:00:00.000Z  2018-11-22T01:00:00.000Z
#
#                 location         parameters     sourceName      sourceNames
# 0             21 de Mayo       [pm25, pm10]  Chile - SINCA  [Chile - SINCA]
# 1             21 de mayo       [pm10, pm25]  Chile - SINCA  [Chile - SINCA]
# 2                 Alerce             [pm25]  Chile - SINCA  [Chile - SINCA]
# 3          Alto Hospicio             [pm25]  Chile - SINCA  [Chile - SINCA]
# 4              Andacollo             [pm10]  Chile - SINCA  [Chile - SINCA]
# 5            Antofagasta  [pm10, pm25, so2]  Chile - SINCA  [Chile - SINCA]
# 6                  Arica             [pm25]  Chile - SINCA  [Chile - SINCA]
# 7              Balneario             [pm25]  Chile - SINCA  [Chile - SINCA]
# 8  Balneario Curanilahue             [pm25]  Chile - SINCA  [Chile - SINCA]
# 9               Bocatoma             [pm10]  Chile - SINCA  [Chile - SINCA]

# %% [markdown]
# - Crear una visualización: Por ejemplo, mostrar en un histograma, cuántas mediciones hay por cada lugar en Chile.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,6))
x_co = chile['city']
y_co = chile['count']

lons = []
lats = []
for i in chile["coordinates"]:
    lons.append(i["longitude"])
    lats.append(i["latitude"])

plt.xlabel('Ciudad')
plt.ylabel('Cantidad de Mediciones')
plt.title('Cantidad de Mediciones por Ciudad')
plt.xticks(rotation=90)

plt.bar(x_co,y_co)
# Out:
# <BarContainer object of 100 artists>

# %% [markdown]
# - Opcional: Mostrar en un mapa de Chile, los lugares dónde se recopila medidades de contaminación.

# %% [markdown]
# # 2. Utilizar el SGBD no relacional Mongo

# %% [markdown]
# MongoDB es un SGBD creado en 2009 (en 2018: version 4). Es un SGBD que no implementa el modelo Relacional (Tabla/Tupla/Claves, datos atómicos) como MySQL o PostgreSQL. La idea inicial de Mongo es ofrecer una solución simple para almacenar objetos JSON.
#
# En Mongo, los conceptos claves son:
# - los <b>Documentos</b>: un documento corresponde a objeto JSON.
# - las <b>Colecciones</b>: una colección es un conjunto de documentos. Nota Bene: en una colección Mongo, los documentos pueden tener una estructura distinta.
#
# En Mongo, no existen directamente los conceptos de Tabla, Tupla o Claves primerias/foraneas. Sin embargo, podemos ver una equivalencia entre Tabla y Colección, y entre Tupla y Documento.

# %% [markdown]
# Verificar que Mongo está instalado correctamente ejecutando:
# - el programa principal del SGBD: <code>mongod &</code> desde un terminal
# - el programa CLI (Command Line Interface): <code>mongo</code>
#
# Vamos a interactuar con Mongo desde un entorno Python, por lo tanto utilizaremos el driver <code>PyMongo</code> (que hay que instalar).

# %%
import pymongo
from pymongo import MongoClient

#Nos conectamos a la instancia de Mongo local, puerto 27017
client = MongoClient('localhost', 27017)

#Nos conectamos a la BD 'notebook5_db', si no existe se crea
db = client['notebook5_db']

#Dentro de la BD, creamos una nueva colección llamada 'personas'
collection = db['personas']

# %% [markdown]
# A continuación, mostramos un ejemplo de como insertar nuevos documentos en una colección:

# %%
#Creamos un nuevo documento

aDocument = {"Nombre":"Juan", "Edad":23, "Asignaturas":["INFO261", "INFO267", "INFO268"] }
otherDocument = {"Nombre":"Maria", "Edad":24, "Asignaturas":["INFO261", "INFO267", "INFO268", "INFO331"] }

collection.insert_many([aDocument,otherDocument])

# %% [markdown]
# Un ejemplo de como consultar nuestra colección agregando un filtro para ver solamente los documentos que tienen un campo "Edad"=23.

# %%
from pprint import pprint

for doc in collection.find({"Edad":24}):
    pprint(doc)
# Out:
# {'Asignaturas': ['INFO261', 'INFO267', 'INFO268', 'INFO331'],
#  'Edad': 24,
#  'Nombre': 'Maria',
#  '_id': ObjectId('5bf63510c159913f88f23a77')}

# %% [markdown]
# Para más detalles sobre la API de Mongo y PyMongo para hacer consultas:
# - http://api.mongodb.com/python/current/tutorial.html
# - https://docs.mongodb.com/manual/crud/

# %% [markdown]
# <b>Ejercicio</b>
# - crear/borrar/modificar documentos desde Mongo CLI y desde PyMongo
# - realizar algunas consultas básicas

# %%
from pprint import pprint

for doc in collection.find({"Asignaturas": 'INFO261' }):
    pprint(doc)
# Out:
# {'Asignaturas': ['INFO261', 'INFO267', 'INFO268'],
#  'Edad': 23,
#  'Nombre': 'Juan',
#  '_id': ObjectId('5bf63510c159913f88f23a76')}
# {'Asignaturas': ['INFO261', 'INFO267', 'INFO268', 'INFO331'],
#  'Edad': 24,
#  'Nombre': 'Maria',
#  '_id': ObjectId('5bf63510c159913f88f23a77')}

# %% [markdown]
# # 3. Trabajo práctico 1
#
# 1. En el marco de un proyecto "Smart City Valdivia", se desea almacenar mediciones de particulas en el aire en Valdivia a partir de la API OpenAQ. Estos datos se cruzaron a posteriori con datos meteorologicos de Valdivia (por ejemplo desde la API https://openweathermap.org/api). Diseñar un modelo Entidad-Asociación que permita almacenar esta información y extenderla a otras ciudades del sur de Chile.
#
# 2. Proponer un modelo de documentos JSON para almacenar está información en Mongo.
#
# 3. Conectarse a la API OpenAQ para empezar a llenar su base de datos Mongo.
#
#
# # 4. Trabajo práctico 2
#
# 1. Conectarse a la API de Twitter.
#
# 2. Recopilar una lista de usuarios que utilizan el hashtag #ValdiviaCL en sus tweets.

# %%
#3 PRACTICO 1

# %%
#(Para el esquema usaremos el formato mongoose)
var calidadAire = new Schema({
    parametro: String,
    valor: Number,
    lugar_momento:{
        fecha_hora: Date,
        nombre_lugar: String,
        latitud: Number,
        longitud: Number
    }
})

var clima = new Schema({
    temperatura: Number,
    estado: String,
    agua_caida: Number,
    velocidad_viento: Number,
    lugar_momento:{
        fecha_hora: Date,
        nombre_lugar: String,
        latitud: Number,
        longitud: Number
    }
})
# Out:
#   File "<ipython-input-1-c6f189c37575>", line 2
#     var calidadAire = new Schema({
#                   ^
# SyntaxError: invalid syntax

# %%
#Crear la base de datos
import pymongo
from pymongo import MongoClient

client = MongoClient('localhost', 27017)
db = client['notebook5_cvaldivia']

collection_ca = db['calidad_aire']
collection_c = db['clima']

# %%
#Obtener los datos desde OpenAQ
import requests
URL = "https://api.openaq.org/v1/measurements?country=CL&city=Valdivia&location=Valdivia"
r = requests.get(url = URL) 
data = r.json() 
print(data)
# Out:
# {'results': [{'location': 'Valdivia', 'value': 132, 'date': {'local': '2018-11-22T02:00:00-03:00', 'utc': '2018-11-22T05:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'pm25', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 2784.74, 'date': {'local': '2018-11-22T02:00:00-03:00', 'utc': '2018-11-22T05:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'co', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 49, 'date': {'local': '2018-11-22T01:00:00-03:00', 'utc': '2018-11-22T04:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'pm25', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 2036.63, 'date': {'local': '2018-11-22T01:00:00-03:00', 'utc': '2018-11-22T04:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'co', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 142, 'date': {'local': '2018-11-22T01:00:00-03:00', 'utc': '2018-11-22T04:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'pm10', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 647.55, 'date': {'local': '2018-11-22T00:00:00-03:00', 'utc': '2018-11-22T03:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'co', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 63, 'date': {'local': '2018-11-22T00:00:00-03:00', 'utc': '2018-11-22T03:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'pm10', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 41, 'date': {'local': '2018-11-22T00:00:00-03:00', 'utc': '2018-11-22T03:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'pm25', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 52, 'date': {'local': '2018-11-21T23:00:00-03:00', 'utc': '2018-11-22T02:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'pm25', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 305.27, 'date': {'local': '2018-11-21T23:00:00-03:00', 'utc': '2018-11-22T02:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'co', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 52, 'date': {'local': '2018-11-21T23:00:00-03:00', 'utc': '2018-11-22T02:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'pm10', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 348.82, 'date': {'local': '2018-11-21T22:00:00-03:00', 'utc': '2018-11-22T01:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'co', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 6.58, 'date': {'local': '2018-11-21T22:00:00-03:00', 'utc': '2018-11-22T01:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'so2', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 60, 'date': {'local': '2018-11-21T22:00:00-03:00', 'utc': '2018-11-22T01:00:00.000Z'}, 'coordinates': {'longitude': -73.22851282209, 'latitude': -39.831316104673}, 'unit': 'µg/m³', 'country': 'CL', 'parameter': 'pm10', 'city': 'Valdivia'}, {'location': 'Valdivia', 'value': 22, 'date': {'local': '2018-11-21T22:00:00-03:00', 'utc': '2018-11-22T01:00:00.000Z'}, 'coordinates':  ...

# %%
#Agregar datos
import json
for i in data:
    for k in data[i]:
        if len(k)>7:
            prueba=k
            loc=prueba['location']
            par=prueba['parameter']
            val=prueba['value']
            lat=prueba['coordinates']['latitude']
            lon=prueba['coordinates']['longitude']
            dat=prueba['date']['local']

            Documento = {
                "Parametro": par,
                "Valor": val,
                "Lugar_Momento": {
                    "fecha_hora": dat,
                    "nombre_lugar": loc,
                    "latitud": lat,
                    "longitud": lon
                }
            }

            collection_ca.insert_many([Documento])

# %%
from pprint import pprint

for doc in collection_ca.find({"Parametro":"pm25"}):
    pprint(doc)
# Out:
# {'Lugar_Momento': {'fecha_hora': '2018-11-22T02:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 132,
#  '_id': ObjectId('5bf651a0c159910c573a7553')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-22T01:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 49,
#  '_id': ObjectId('5bf651a1c159910c573a7555')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-22T00:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 41,
#  '_id': ObjectId('5bf651a1c159910c573a755a')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T23:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 52,
#  '_id': ObjectId('5bf651a1c159910c573a755b')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T22:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 22,
#  '_id': ObjectId('5bf651a1c159910c573a7561')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T21:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 0,
#  '_id': ObjectId('5bf651a1c159910c573a7563')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T17:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 2,
#  '_id': ObjectId('5bf651a1c159910c573a7567')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T16:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 2,
#  '_id': ObjectId('5bf651a1c159910c573a7568')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T15:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 5,
#  '_id': ObjectId('5bf651a1c159910c573a756c')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T14:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 6,
#  '_id': ObjectId('5bf651a1c159910c573a756e')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T12:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 2,
#  '_id': ObjectId('5bf651a1c159910c573a7573')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T11:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 4,
#  '_id': ObjectId('5bf651a1c159910c573a7576')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T10:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 3,
#  '_id': ObjectId('5bf651a1c159910c573a7577')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T09:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 4,
#  '_id': ObjectId('5bf651a1c159910c573a757a')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T08:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 1,
#  '_id': ObjectId('5bf651a1c159910c573a757f')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T07:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 1,
#  '_id': ObjectId('5bf651a1c159910c573a7580')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T06:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 2,
#  '_id': ObjectId('5bf651a1c159910c573a7584')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T05:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 6,
#  '_id': ObjectId('5bf651a1c159910c573a7586')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T04:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 2,
#  '_id': ObjectId('5bf651a1c159910c573a7589')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T03:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 2,
#  '_id': ObjectId('5bf651a1c159910c573a758e')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T02:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 3,
#  '_id': ObjectId('5bf651a1c159910c573a758f')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T01:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 5,
#  '_id': ObjectId('5bf651a1c159910c573a7594')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-21T00:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 4,
#  '_id': ObjectId('5bf651a1c159910c573a7595')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-20T23:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 4,
#  '_id': ObjectId('5bf651a1c159910c573a759a')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-20T22:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 4,
#  '_id': ObjectId('5bf651a1c159910c573a759d')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-20T21:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 1,
#  '_id': ObjectId('5bf651a1c159910c573a759e')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-20T20:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 2,
#  '_id': ObjectId('5bf651a1c159910c573a75a1')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-20T19:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 2,
#  '_id': ObjectId('5bf651a1c159910c573a75a6')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-20T18:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 4,
#  '_id': ObjectId('5bf651a1c159910c573a75a7')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-20T17:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 5,
#  '_id': ObjectId('5bf651a1c159910c573a75a9')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-20T16:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 3,
#  '_id': ObjectId('5bf651a1c159910c573a75ae')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-20T15:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 4,
#  '_id': ObjectId('5bf651a1c159910c573a75af')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-20T14:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 7,
#  '_id': ObjectId('5bf651a1c159910c573a75b3')}
# {'Lugar_Momento': {'fecha_hora': '2018-11-20T13:00:00-03:00',
#                    'latitud': -39.831316104673,
#                    'longitud': -73.22851282209,
#                    'nombre_lugar': 'Valdivia'},
#  'Parametro': 'pm25',
#  'Valor': 7,
#  '_id': ObjectId('5bf651a1c159910c573a75b5')}

# %%
#4 PRACTICO 2

# %%
import tweepy #sudo pip3 install tweepy
 

consumer_key="VrrWb0wDoG2YvkVOXY0krIdP1"
consumer_secret="LINi3AaqDBYD4OeYPV752WuKMMgPMSo1evUhOu0afQwjdaK5tL"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
access_token="976231636642779137-3usy7F6Misxicy7WLQA3wbUJckWtjEb"
access_token_secret="n5QG8GnHdWGNRCVNGTc8JSlqePbmi3dBuumhpWjknBKYG"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
 
api = tweepy.API(auth)

# %%
query = '#ValdiviaCL'
max_tweets = 100
listHast = [status for status in tweepy.Cursor(api.search, q=query).items(max_tweets)]

# %%
print("Lista de ususario que ocuparon #ValdiviaCl")
for rt in listHast:
    print ("@"+rt.user.screen_name)
# Out:
# Lista de ususario que ocuparon #ValdiviaCl
# @jocygothie
# @ddanivega
# @RespiraValdivia
# @vanferra
# @JoanBond
# @johnny_reys
# @rbarralesr
# @SaldivarG_L
# @openmapchile
# @carlosc33569564
# @zatitta
# @zatitta
# @EAstigue
# @Saesa_
# @BeelzemonCL
# @BeelzemonCL
# @patriciorosas
# @Cdvb2008
# @rioenlinea
# @dddiaz01
# @ManiaFmCh
# @MarceloRojasA
# @AlejandroHennic
# @pavloandres29
# @rociojana
# @rociojana
# @piponXVI
# @jxan_cc
# @Jorge_ZamoranoG
# @diario_valdivia
# @socecol
# @socecol
# @rociojana
# @lalitafutrono
# @Manzanotuitero
# @RespiraValdivia
# @Tatiana81116976
# @CMontrosis
# @panxoandres
# @socecol
# @socecol
# @YoSoy_SerdeAmor
# @Manzanotuitero
# @doggy532
# @aeloiza27
# @patriciorosas
# @aeloiza27
# @INSAT_VALD
# @claudiodaniel23
# @messinagodoy
# @villanix
# @fouremusica
# @sakuramunoz
# @La_Marce__
# @ObrequeMauricio
# @giespinoza
# @CristinaMachuca
# @Diego_HerreraRe
# @bancadaPSchile
# @lisetchepare
# @lisetchepare
# @Katz010
# @dannyunix
# @Elsita_OS
# @Marcelagp2
# @Claudio_Suazo_
# @arteluzmarina
# @Ximenalunecke
# @CristobalCar
# @Patcuevas2
# @fcarojasp
# @Barney_san
# @lafurtilla
# @Meteo_valdivia
# @lpalma80
# @cdia2az
# @RespiraValdivia
# @Francis84664264
# @GobValdivia
# @pavloandres29
# @jobecerra
# @CGlo__ria
# @ivon09811882
# @AcunaPaola
# @marcos_ilabaca
# @PatoGarridoG
# @patriciorosas
# @PatoGarridoG
# @Ryszard88
# @riosdelrio
# @tatapelao05
# @estef_fem
# @Valdivia2015
# @marcos_ilabaca
# @Valdivicho
# @Elsita_OS
# @Solertm
# @RedInvestChile
# @ValdiviaTiempo
# @garypablos
